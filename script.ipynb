# %% [markdown]
# # Color with music
#
# This project will work with the following element:
# - midi keyboard as inputs
# - pygame as screen, real-time updates

# %%
import mido
from mido import MidiFile

# %%
msg = mido.Message('note_on', note=60)
msg.type

# %%
msg.note

# %%
msg.bytes()

# %%
midi_file_path = 'SuperMarioBrothers.mid'
mid = MidiFile(midi_file_path)

# %%
for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)

# %%
for msg in mid.play():
    bytes = msg.bytes()
    print(f"length: {len(bytes)}")
    print(f"bytes: {bytes}")
    print(f"message: {msg}")
    print("================================")

# %% [markdown]
# ## Version 0.1 (POC)
# a `Message` has a few noteworthy properties that might be useful:
# - `Note` (int): The midi number (could be translated to a musical note: 57 is `A3` in musical terms)
# - `type` (Enum): indicates what type of input is used. Focus only on `note_on` and `note_off` for now?
# - `channel` (int): will not be used in the final version because it will only have a single channel?
# - `velocity` (int): indicates the velocity of note, meaning how hard the key is pushed --> alpha value?
# - `time` (float): The timestamp of the message in ticks. The ticks are a unit of time in the MIDI file. might be useful
#
# These properties need to be mapped to a few controls:
# - color + alpha
# - brush
# - location + direction
# - action
#
# The following steps will be taken for version 0.1:
# - color + alpha selection
#     - colors: 7 base colors (base notes: A, B, C, D, E, F, G)
#         - pallet: https://coolors.co/palette/0ad2ff-2962ff-9500ff-ff0059-ff8c00-b4e600-0fffdb
#     - erasers: 5 sharp (A#, C#, D#, F#, G#). this means that some colors are not removable
#
# - location + direction
# - rendering

# %% [markdown]
# ### color + alpha
# Color mapping can be done by using the actual note. this provides two options for creating creating a color: the midi-value or the name. The name provides use with a letter (the name of the note: A, B, C, D, E, F, G), sharp or not, and a number (the octave). The midi number is just an integer that can be mapped on the name.
#
# using the name we can map 6 base colors, with 2 extra colors if we take the sharps. and the octave could add some random saturation.
#
# This would provide some logic to all keys making it possible to create a schema that provides some color information to users.
#
# Otherwise, if randomness is more the goal then using a `hash` function for converting the midi-value to RGB values is the way to go. because a `hash` would create the same color of the same input, it would allow more range in colors. each key would present a new color.
#
# for the alpha value, using `velocity` seems the best way to go. If the value cannot be mapped between 0 and 1 (or 0 and 255) then not using it for alpha is a good way.

# %% [markdown]
# ### brush
# The brush "type"/form needs to be made. It might be interesting to have different message types that change brushes over time (version 2 maybe?).

# %% [markdown]
# ### location + direction
# the location of the brush and the direction that needs to be drawn in is more difficult to map. `note_on` and `note_off`.
#
# Given that notes tend to be short, using `dots` seems the best way to go.
# for the direction, it should start at a random coordinate in a random direction, with again `velocity` the initial inertia of the stroke. the line is drawn until the `off` message is signaled or the border is hit.
# the stroke after starts at the end coordinates of the previous stroke for that note with a new random direction. If the border is crossed, the end coordinate is the point of the border.

# %% [markdown]
# ## overlapping actions
# notes can be pressed at the same time. This provides one complication: keep track of the `note_on` and `note_off` message.
# The on and off message both describe the same midi key so keep a `Dict` for the note (and channel?) and its status (on or off  --> `Bool`).
# When the note is `on` the action is performed until the `off` message appears

# %% [markdown]
# ### actions
# Add erase function? if so, which keys? The option to erase might be nice but also would defeat the purpose of the painting.
#
# 2 things might be fun to add:
# - save picture (mail it to yourself?)
# - new work (clear canvas and memory)

# %%
keyboard_name = "Impact GX Mini MIDI1"

# %%
def on_midi_message(message):
    print(f"Received MIDI message: {message}")

# Replace 'Your_MIDI_Keyboard_Name' with the actual name of your MIDI keyboard
input_port = mido.open_input(keyboard_name, callback=on_midi_message)

try:
    print(f"Listening for MIDI input from {keyboard_name}. Press Ctrl+C to exit.")
    while True:
        # The callback function on_midi_message will be called for each received MIDI message
        pass
except KeyboardInterrupt:
    print("\nExiting MIDI listener.")
finally:
    input_port.close()
# Out:
# Listening for MIDI input from Impact GX Mini MIDI1. Press Ctrl+C to exit.
# Received MIDI message: note_on channel=0 note=53 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=53 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=112 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=124 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=124 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=124 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=16 time=0
# Received MIDI message: note_on channel=0 note=57 velocity=0 time=0
# Received MIDI message: pitchwheel channel=0 pitch=128 time=0
# Received MIDI message: pitchwheel channel=0 pitch=256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=640 time=0
# Received MIDI message: pitchwheel channel=0 pitch=768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1152 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1664 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1792 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2176 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2304 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2432 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2688 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2944 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3072 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3200 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3328 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3456 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3584 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3712 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3840 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4096 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4224 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4352 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4480 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4608 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4736 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4992 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5376 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5632 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5760 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6016 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6272 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6400 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6656 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6784 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7040 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7296 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7424 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7680 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7808 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=8191 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7808 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7680 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7424 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7296 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7040 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6784 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6656 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6400 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6272 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6016 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5760 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5632 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5376 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5248 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4992 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4736 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4480 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4224 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3712 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3200 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=0 time=0
# Received MIDI message: pitchwheel channel=0 pitch=128 time=0
# Received MIDI message: pitchwheel channel=0 pitch=256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=640 time=0
# Received MIDI message: pitchwheel channel=0 pitch=768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1152 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1664 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1792 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2176 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2304 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2432 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2688 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2944 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3072 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3200 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3328 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3456 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3584 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3712 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3840 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4096 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4224 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4352 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4480 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4608 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4736 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4992 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5248 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5376 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5632 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5760 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6016 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6272 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6400 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6656 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6784 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7040 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7296 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7424 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7680 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7808 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=8191 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7808 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7680 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7424 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7296 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=7040 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6784 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6656 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6400 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6272 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=6016 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5760 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5632 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5376 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5248 time=0
# Received MIDI message: pitchwheel channel=0 pitch=5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4992 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4736 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4608 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4480 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4352 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4224 time=0
# Received MIDI message: pitchwheel channel=0 pitch=4096 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3840 time=0
# Received MIDI message: pitchwheel channel=0 pitch=3456 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=0 time=0
# Received MIDI message: pitchwheel channel=0 pitch=128 time=0
# Received MIDI message: pitchwheel channel=0 pitch=256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=640 time=0
# Received MIDI message: pitchwheel channel=0 pitch=768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1152 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1664 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1792 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2176 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2304 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2432 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2688 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2432 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2304 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2176 time=0
# Received MIDI message: pitchwheel channel=0 pitch=2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1792 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1664 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1152 time=0
# Received MIDI message: pitchwheel channel=0 pitch=1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=640 time=0
# Received MIDI message: pitchwheel channel=0 pitch=512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=128 time=0
# Received MIDI message: pitchwheel channel=0 pitch=0 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1792 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2304 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2432 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2944 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3072 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3328 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3456 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3584 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3840 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3968 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4096 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4352 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4480 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4608 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4992 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5376 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5632 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6016 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6400 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6656 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7040 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7424 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7680 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-8064 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-8192 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-8064 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7680 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7424 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7040 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6656 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6400 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6016 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5632 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5376 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4992 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4608 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4480 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4352 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4096 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3968 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3840 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3584 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3456 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3328 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3072 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2944 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2432 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2304 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1792 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=0 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-384 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1280 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1792 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2432 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3072 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3456 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3840 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4096 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4480 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-8192 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-8064 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7936 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7680 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7552 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7424 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7168 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-7040 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6912 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6656 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6528 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6400 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6144 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-6016 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5888 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5632 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5504 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5376 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-5120 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4864 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4608 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-4352 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3968 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3584 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3328 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-3072 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2816 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2560 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2304 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-2048 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1920 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1536 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1408 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-1024 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-896 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-768 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-512 time=0
# Received MIDI message: pitchwheel channel=0 pitch=-256 time=0
# Received MIDI message: pitchwheel channel=0 pitch=0 time=0
# Received MIDI message: control_change channel=0 control=4 value=3 time=0
# Received MIDI message: control_change channel=0 control=4 value=10 time=0
# Received MIDI message: control_change channel=0 control=4 value=18 time=0
# Received MIDI message: control_change channel=0 control=4 value=26 time=0
# Received MIDI message: control_change channel=0 control=4 value=36 time=0
# Received MIDI message: control_change channel=0 control=4 value=45 time=0
# Received MIDI message: control_change channel=0 control=4 value=53 time=0
# Received MIDI message: control_change channel=0 control=4 value=66 time=0
# Received MIDI message: control_change channel=0 control=4 value=77 time=0
# Received MIDI message: control_change channel=0 control=4 value=90 time=0
# Received MIDI message: control_change channel=0 control=4 value=104 time=0
# Received MIDI message: control_change channel=0 control=4 value=118 time=0
# Received MIDI message: control_change channel=0 control=4 value=127 time=0
# Received MIDI message: control_change channel=0 control=4 value=124 time=0
# Received MIDI message: control_change channel=0 control=4 value=121 time=0
# Received MIDI message: control_change channel=0 control=4 value=117 time=0
# Received MIDI message: control_change channel=0 control=4 value=114 time=0
# Received MIDI message: control_change channel=0 control=4 value=110 time=0
# Received MIDI message: control_change channel=0 control=4 value=107 time=0
# Received MIDI message: control_change channel=0 control=4 value=103 time=0
# Received MIDI message: control_change channel=0 control=4 value=101 time=0
# Received MIDI message: control_change channel=0 control=4 value=98 time=0
# Received MIDI message: control_change channel=0 control=4 value=94 time=0
# Received MIDI message: control_change channel=0 control=4 value=89 time=0
# Received MIDI message: control_change channel=0 control=4 value=85 time=0
# Received MIDI message: control_change channel=0 control=4 value=83 time=0
# Received MIDI message: control_change channel=0 control=4 value=80 time=0
# Received MIDI message: control_change channel=0 control=4 value=76 time=0
# Received MIDI message: control_change channel=0 control=4 value=73 time=0
# Received MIDI message: control_change channel=0 control=4 value=70 time=0
# Received MIDI message: control_change channel=0 control=4 value=67 time=0
# Received MIDI message: control_change channel=0 control=4 value=64 time=0
# Received MIDI message: control_change channel=0 control=4 value=60 time=0
# Received MIDI message: control_change channel=0 control=4 value=56 time=0
# Received MIDI message: control_change channel=0 control=4 value=53 time=0
# Received MIDI message: control_change channel=0 control=4 value=50 time=0
# Received MIDI message: control_change channel=0 control=4 value=47 time=0
# Received MIDI message: control_change channel=0 control=4 value=43 time=0
# Received MIDI message: control_change channel=0 control=4 value=40 time=0
# Received MIDI message: control_change channel=0 control=4 value=37 time=0
# Received MIDI message: control_change channel=0 control=4 value=33 time=0
# Received MIDI message: control_change channel=0 control=4 value=30 time=0
# Received MIDI message: control_change channel=0 control=4 value=27 time=0
# Received MIDI message: control_change channel=0 control=4 value=25 time=0
# Received MIDI message: control_change channel=0 control=4 value=21 time=0
# Received MIDI message: control_change channel=0 control=4 value=17 time=0
# Received MIDI message: control_change channel=0 control=4 value=14 time=0
# Received MIDI message: control_change channel=0 control=4 value=10 time=0
# Received MIDI message: control_change channel=0 control=4 value=6 time=0
# Received MIDI message: control_change channel=0 control=4 value=3 time=0
# Received MIDI message: control_change channel=0 control=4 value=0 time=0
# Received MIDI message: note_on channel=0 note=59 velocity=122 time=0
# Received MIDI message: control_change channel=0 control=1 value=3 time=0
# Received MIDI message: control_change channel=0 control=1 value=7 time=0
# Received MIDI message: control_change channel=0 control=1 value=10 time=0
# Received MIDI message: control_change channel=0 control=1 value=14 time=0
# Received MIDI message: control_change channel=0 control=1 value=17 time=0
# Received MIDI message: control_change channel=0 control=1 value=21 time=0
# Received MIDI message: control_change channel=0 control=1 value=25 time=0
# Received MIDI message: control_change channel=0 control=1 value=29 time=0
# Received MIDI message: control_change channel=0 control=1 value=32 time=0
# Received MIDI message: control_change channel=0 control=1 value=36 time=0
# Received MIDI message: control_change channel=0 control=1 value=39 time=0
# Received MIDI message: control_change channel=0 control=1 value=43 time=0
# Received MIDI message: control_change channel=0 control=1 value=47 time=0
# Received MIDI message: control_change channel=0 control=1 value=51 time=0
# Received MIDI message: control_change channel=0 control=1 value=54 time=0
# Received MIDI message: control_change channel=0 control=1 value=59 time=0
# Received MIDI message: control_change channel=0 control=1 value=63 time=0
# Received MIDI message: control_change channel=0 control=1 value=66 time=0
# Received MIDI message: control_change channel=0 control=1 value=69 time=0
# Received MIDI message: control_change channel=0 control=1 value=73 time=0
# Received MIDI message: control_change channel=0 control=1 value=76 time=0
# Received MIDI message: control_change channel=0 control=1 value=80 time=0
# Received MIDI message: control_change channel=0 control=1 value=84 time=0
# Received MIDI message: control_change channel=0 control=1 value=88 time=0
# Received MIDI message: control_change channel=0 control=1 value=93 time=0
# Received MIDI message: control_change channel=0 control=1 value=95 time=0
# Received MIDI message: control_change channel=0 control=1 value=100 time=0
# Received MIDI message: control_change channel=0 control=1 value=103 time=0
# Received MIDI message: control_change channel=0 control=1 value=107 time=0
# Received MIDI message: control_change channel=0 control=1 value=111 time=0
# Received MIDI message: control_change channel=0 control=1 value=115 time=0
# Received MIDI message: control_change channel=0 control=1 value=119 time=0
# Received MIDI message: control_change channel=0 control=1 value=123 time=0
# Received MIDI message: control_change channel=0 control=1 value=126 time=0
# Received MIDI message: control_change channel=0 control=1 value=127 time=0
# Received MIDI message: control_change channel=0 control=1 value=126 time=0
# Received MIDI message: control_change channel=0 control=1 value=122 time=0
# Received MIDI message: control_change channel=0 control=1 value=118 time=0
# Received MIDI message: control_change channel=0 control=1 value=114 time=0
# Received MIDI message: control_change channel=0 control=1 value=110 time=0
# Received MIDI message: control_change channel=0 control=1 value=106 time=0
# Received MIDI message: control_change channel=0 control=1 value=101 time=0
# Received MIDI message: control_change channel=0 control=1 value=96 time=0
# Received MIDI message: control_change channel=0 control=1 value=93 time=0
# Received MIDI message: control_change channel=0 control=1 value=88 time=0
# Received MIDI message: control_change channel=0 control=1 value=83 time=0
# Received MIDI message: control_change channel=0 control=1 value=78 time=0
# Received MIDI message: control_change channel=0 control=1 value=73 time=0
# Received MIDI message: control_change channel=0 control=1 value=68 time=0
# Received MIDI message: control_change channel=0 control=1 value=63 time=0
# Received MIDI message: control_change channel=0 control=1 value=58 time=0
# Received MIDI message: control_change channel=0 control=1 value=53 time=0
# Received MIDI message: control_change channel=0 control=1 value=46 time=0
# Received MIDI message: control_change channel=0 control=1 value=41 time=0
# Received MIDI message: control_change channel=0 control=1 value=35 time=0
# Received MIDI message: control_change channel=0 control=1 value=29 time=0
# Received MIDI message: control_change channel=0 control=1 value=24 time=0
# Received MIDI message: control_change channel=0 control=1 value=17 time=0
# Received MIDI message: control_change channel=0 control=1 value=10 time=0
# Received MIDI message: control_change channel=0 control=1 value=4 time=0
# Received MIDI message: control_change channel=0 control=1 value=0 time=0
# Received MIDI message: control_change channel=0 control=4 value=1 time=0
# Received MIDI message: control_change channel=0 control=4 value=4 time=0
# Received MIDI message: control_change channel=0 control=4 value=6 time=0
# Received MIDI message: control_change channel=0 control=4 value=10 time=0
# Received MIDI message: control_change channel=0 control=4 value=13 time=0
# Received MIDI message: control_change channel=0 control=4 value=15 time=0
# Received MIDI message: control_change channel=0 control=4 value=18 time=0
# Received MIDI message: control_change channel=0 control=4 value=20 time=0
# Received MIDI message: control_change channel=0 control=4 value=23 time=0
# Received MIDI message: control_change channel=0 control=4 value=26 time=0
# Received MIDI message: control_change channel=0 control=4 value=30 time=0
# Received MIDI message: control_change channel=0 control=4 value=33 time=0
# Received MIDI message: control_change channel=0 control=4 value=37 time=0
# Received MIDI message: control_change channel=0 control=4 value=40 time=0
# Received MIDI message: control_change channel=0 control=4 value=43 time=0
# Received MIDI message: control_change channel=0 control=4 value=47 time=0
# Received MIDI message: control_change channel=0 control=4 value=49 time=0
# Received MIDI message: control_change channel=0 control=4 value=52 time=0
# Received MIDI message: control_change channel=0 control=4 value=55 time=0
# Received MIDI message: control_change channel=0 control=4 value=60 time=0
# Received MIDI message: control_change channel=0 control=4 value=64 time=0
# Received MIDI message: control_change channel=0 control=4 value=67 time=0
# Received MIDI message: control_change channel=0 control=4 value=70 time=0
# Received MIDI message: control_change channel=0 control=4 value=72 time=0
# Received MIDI message: control_change channel=0 control=4 value=76 time=0
# Received MIDI message: control_change channel=0 control=4 value=80 time=0
# Received MIDI message: control_change channel=0 control=4 value=83 time=0
# Received MIDI message: control_change channel=0 control=4 value=87 time=0
# Received MIDI message: control_change channel=0 control=4 value=90 time=0
# Received MIDI message: control_change channel=0 control=4 value=94 time=0
# Received MIDI message: control_change channel=0 control=4 value=98 time=0
# Received MIDI message: control_change channel=0 control=4 value=102 time=0
# Received MIDI message: control_change channel=0 control=4 value=106 time=0
# Received MIDI message: control_change channel=0 control=4 value=110 time=0
# Received MIDI message: control_change channel=0 control=4 value=114 time=0
# Received MIDI message: control_change channel=0 control=4 value=117 time=0
# Received MIDI message: control_change channel=0 control=4 value=121 time=0
# Received MIDI message: control_change channel=0 control=4 value=124 time=0
# Received MIDI message: control_change channel=0 control=4 value=127 time=0
# Received MIDI message: control_change channel=0 control=4 value=125 time=0
# Received MIDI message: control_change channel=0 control=4 value=121 time=0
# Received MIDI message: control_change channel=0 control=4 value=114 time=0
# Received MIDI message: control_change channel=0 control=4 value=109 time=0
# Received MIDI message: control_change channel=0 control=4 value=103 time=0
# Received MIDI message: control_change channel=0 control=4 value=98 time=0
# Received MIDI message: control_change channel=0 control=4 value=90 time=0
# Received MIDI message: control_change channel=0 control=4 value=83 time=0
# Received MIDI message: control_change channel=0 control=4 value=78 time=0
# Received MIDI message: control_change channel=0 control=4 value=73 time=0
# Received MIDI message: control_change channel=0 control=4 value=67 time=0
# Received MIDI message: control_change channel=0 control=4 value=59 time=0
# Received MIDI message: control_change channel=0 control=4 value=51 time=0
# Received MIDI message: control_change channel=0 control=4 value=46 time=0
# Received MIDI message: control_change channel=0 control=4 value=40 time=0
# Received MIDI message: control_change channel=0 control=4 value=33 time=0
# Received MIDI message: control_change channel=0 control=4 value=26 time=0
# Received MIDI message: control_change channel=0 control=4 value=18 time=0
# Received MIDI message: control_change channel=0 control=4 value=11 time=0
# Received MIDI message: control_change channel=0 control=4 value=3 time=0
# Received MIDI message: control_change channel=0 control=4 value=0 time=0
# Received MIDI message: control_change channel=0 control=1 value=1 time=0
# Received MIDI message: control_change channel=0 control=1 value=2 time=0
# Received MIDI message: control_change channel=0 control=1 value=3 time=0
# Received MIDI message: control_change channel=0 control=1 value=4 time=0
# Received MIDI message: control_change channel=0 control=1 value=5 time=0
# Received MIDI message: control_change channel=0 control=1 value=0 time=0
# Received MIDI message: note_on channel=0 note=59 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=59 velocity=118 time=0
# Received MIDI message: control_change channel=0 control=1 value=1 time=0
# Received MIDI message: control_change channel=0 control=1 value=4 time=0
# Received MIDI message: control_change channel=0 control=1 value=7 time=0
# Received MIDI message: control_change channel=0 control=1 value=10 time=0
# Received MIDI message: control_change channel=0 control=1 value=12 time=0
# Received MIDI message: control_change channel=0 control=1 value=15 time=0
# Received MIDI message: control_change channel=0 control=1 value=17 time=0
# Received MIDI message: control_change channel=0 control=1 value=20 time=0
# Received MIDI message: control_change channel=0 control=1 value=23 time=0
# Received MIDI message: control_change channel=0 control=1 value=26 time=0
# Received MIDI message: control_change channel=0 control=1 value=28 time=0
# Received MIDI message: control_change channel=0 control=1 value=31 time=0
# Received MIDI message: control_change channel=0 control=1 value=34 time=0
# Received MIDI message: control_change channel=0 control=1 value=37 time=0
# Received MIDI message: control_change channel=0 control=1 value=40 time=0
# Received MIDI message: control_change channel=0 control=1 value=43 time=0
# Received MIDI message: control_change channel=0 control=1 value=46 time=0
# Received MIDI message: control_change channel=0 control=1 value=49 time=0
# Received MIDI message: control_change channel=0 control=1 value=53 time=0
# Received MIDI message: control_change channel=0 control=1 value=56 time=0
# Received MIDI message: control_change channel=0 control=1 value=58 time=0
# Received MIDI message: control_change channel=0 control=1 value=62 time=0
# Received MIDI message: control_change channel=0 control=1 value=65 time=0
# Received MIDI message: control_change channel=0 control=1 value=68 time=0
# Received MIDI message: control_change channel=0 control=1 value=71 time=0
# Received MIDI message: control_change channel=0 control=1 value=74 time=0
# Received MIDI message: control_change channel=0 control=1 value=78 time=0
# Received MIDI message: control_change channel=0 control=1 value=81 time=0
# Received MIDI message: control_change channel=0 control=1 value=84 time=0
# Received MIDI message: control_change channel=0 control=1 value=87 time=0
# Received MIDI message: control_change channel=0 control=1 value=91 time=0
# Received MIDI message: control_change channel=0 control=1 value=94 time=0
# Received MIDI message: control_change channel=0 control=1 value=97 time=0
# Received MIDI message: control_change channel=0 control=1 value=101 time=0
# Received MIDI message: control_change channel=0 control=1 value=104 time=0
# Received MIDI message: control_change channel=0 control=1 value=107 time=0
# Received MIDI message: control_change channel=0 control=1 value=111 time=0
# Received MIDI message: control_change channel=0 control=1 value=115 time=0
# Received MIDI message: control_change channel=0 control=1 value=118 time=0
# Received MIDI message: control_change channel=0 control=1 value=122 time=0
# Received MIDI message: control_change channel=0 control=1 value=126 time=0
# Received MIDI message: control_change channel=0 control=1 value=127 time=0
# Received MIDI message: control_change channel=0 control=1 value=126 time=0
# Received MIDI message: control_change channel=0 control=1 value=124 time=0
# Received MIDI message: control_change channel=0 control=1 value=121 time=0
# Received MIDI message: control_change channel=0 control=1 value=119 time=0
# Received MIDI message: control_change channel=0 control=1 value=117 time=0
# Received MIDI message: control_change channel=0 control=1 value=114 time=0
# Received MIDI message: control_change channel=0 control=1 value=112 time=0
# Received MIDI message: control_change channel=0 control=1 value=109 time=0
# Received MIDI message: control_change channel=0 control=1 value=107 time=0
# Received MIDI message: control_change channel=0 control=1 value=104 time=0
# Received MIDI message: control_change channel=0 control=1 value=102 time=0
# Received MIDI message: control_change channel=0 control=1 value=98 time=0
# Received MIDI message: control_change channel=0 control=1 value=96 time=0
# Received MIDI message: control_change channel=0 control=1 value=93 time=0
# Received MIDI message: control_change channel=0 control=1 value=91 time=0
# Received MIDI message: control_change channel=0 control=1 value=88 time=0
# Received MIDI message: control_change channel=0 control=1 value=84 time=0
# Received MIDI message: control_change channel=0 control=1 value=80 time=0
# Received MIDI message: control_change channel=0 control=1 value=78 time=0
# Received MIDI message: control_change channel=0 control=1 value=74 time=0
# Received MIDI message: control_change channel=0 control=1 value=72 time=0
# Received MIDI message: control_change channel=0 control=1 value=69 time=0
# Received MIDI message: control_change channel=0 control=1 value=65 time=0
# Received MIDI message: control_change channel=0 control=1 value=63 time=0
# Received MIDI message: control_change channel=0 control=1 value=60 time=0
# Received MIDI message: control_change channel=0 control=1 value=56 time=0
# Received MIDI message: control_change channel=0 control=1 value=53 time=0
# Received MIDI message: control_change channel=0 control=1 value=51 time=0
# Received MIDI message: control_change channel=0 control=1 value=47 time=0
# Received MIDI message: control_change channel=0 control=1 value=43 time=0
# Received MIDI message: control_change channel=0 control=1 value=40 time=0
# Received MIDI message: control_change channel=0 control=1 value=37 time=0
# Received MIDI message: control_change channel=0 control=1 value=33 time=0
# Received MIDI message: control_change channel=0 control=1 value=29 time=0
# Received MIDI message: control_change channel=0 control=1 value=25 time=0
# Received MIDI message: control_change channel=0 control=1 value=21 time=0
# Received MIDI message: control_change channel=0 control=1 value=16 time=0
# Received MIDI message: control_change channel=0 control=1 value=11 time=0
# Received MIDI message: control_change channel=0 control=1 value=5 time=0
# Received MIDI message: control_change channel=0 control=1 value=0 time=0
# Received MIDI message: control_change channel=0 control=4 value=1 time=0
# Received MIDI message: control_change channel=0 control=4 value=6 time=0
# Received MIDI message: control_change channel=0 control=4 value=11 time=0
# Received MIDI message: control_change channel=0 control=4 value=15 time=0
# Received MIDI message: control_change channel=0 control=4 value=21 time=0
# Received MIDI message: control_change channel=0 control=4 value=26 time=0
# Received MIDI message: control_change channel=0 control=4 value=30 time=0
# Received MIDI message: control_change channel=0 control=4 value=35 time=0
# Received MIDI message: control_change channel=0 control=4 value=40 time=0
# Received MIDI message: control_change channel=0 control=4 value=46 time=0
# Received MIDI message: control_change channel=0 control=4 value=49 time=0
# Received MIDI message: control_change channel=0 control=4 value=54 time=0
# Received MIDI message: control_change channel=0 control=4 value=63 time=0
# Received MIDI message: control_change channel=0 control=4 value=67 time=0
# Received MIDI message: control_change channel=0 control=4 value=73 time=0
# Received MIDI message: control_change channel=0 control=4 value=77 time=0
# Received MIDI message: control_change channel=0 control=4 value=83 time=0
# Received MIDI message: control_change channel=0 control=4 value=88 time=0
# Received MIDI message: control_change channel=0 control=4 value=94 time=0
# Received MIDI message: control_change channel=0 control=4 value=100 time=0
# Received MIDI message: control_change channel=0 control=4 value=106 time=0
# Received MIDI message: control_change channel=0 control=4 value=112 time=0
# Received MIDI message: control_change channel=0 control=4 value=117 time=0
# Received MIDI message: control_change channel=0 control=4 value=122 time=0
# Received MIDI message: control_change channel=0 control=4 value=127 time=0
# Received MIDI message: control_change channel=0 control=4 value=126 time=0
# Received MIDI message: control_change channel=0 control=4 value=123 time=0
# Received MIDI message: control_change channel=0 control=4 value=121 time=0
# Received MIDI message: control_change channel=0 control=4 value=119 time=0
# Received MIDI message: control_change channel=0 control=4 value=117 time=0
# Received MIDI message: control_change channel=0 control=4 value=115 time=0
# Received MIDI message: control_change channel=0 control=4 value=113 time=0
# Received MIDI message: control_change channel=0 control=4 value=111 time=0
# ...
# Received MIDI message: note_on channel=1 note=53 velocity=112 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=57 velocity=113 time=0
# Received MIDI message: note_on channel=1 note=53 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=107 time=0
# Received MIDI message: note_on channel=1 note=57 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=59 velocity=100 time=0
# Received MIDI message: note_on channel=1 note=57 velocity=101 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=122 time=0
# Received MIDI message: note_on channel=1 note=57 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=59 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=90 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=112 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=85 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=84 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=103 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=112 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=124 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=102 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=119 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=124 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=107 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=97 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=119 time=0
# Received MIDI message: note_on channel=1 note=86 velocity=16 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=99 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=93 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=102 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=73 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=87 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=48 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=99 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=98 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=86 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=106 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=100 time=0
# Received MIDI message: note_on channel=1 note=52 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=86 velocity=25 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=95 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=89 time=0
# Received MIDI message: note_on channel=1 note=100 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=82 time=0
# Received MIDI message: note_on channel=1 note=86 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=84 velocity=82 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=103 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=32 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=81 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=16 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=110 time=0
# Received MIDI message: note_on channel=0 note=84 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=107 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=100 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=111 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=107 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=71 velocity=107 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=69 velocity=80 time=0
# Received MIDI message: note_on channel=0 note=71 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=87 time=0
# Received MIDI message: note_on channel=0 note=69 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=65 velocity=31 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=65 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=60 velocity=124 time=0
# Received MIDI message: note_on channel=0 note=65 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=74 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=110 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=69 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=109 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=111 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=110 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=65 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=60 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=69 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=125 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=110 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=111 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=35 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=124 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=28 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=71 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=71 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=48 velocity=122 time=0
# Received MIDI message: note_on channel=1 note=48 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=120 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=126 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=125 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=126 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=60 velocity=96 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=119 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=114 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=122 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=21 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=60 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=84 velocity=37 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=33 time=0
# Received MIDI message: note_on channel=0 note=84 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=107 velocity=103 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=62 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=1 note=107 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=90 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=60 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=89 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=45 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=89 time=0
# Received MIDI message: note_on channel=0 note=69 velocity=17 time=0
# Received MIDI message: note_on channel=0 note=65 velocity=56 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=58 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=65 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=69 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=107 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=77 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=49 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=53 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=36 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=93 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=77 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=92 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=73 time=0
# Received MIDI message: note_on channel=0 note=60 velocity=62 time=0
# Received MIDI message: note_on channel=0 note=71 velocity=127 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=39 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=35 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=16 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=16 time=0
# Received MIDI message: note_on channel=0 note=77 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=71 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=64 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=62 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=60 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=67 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=112 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=93 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=76 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=93 time=0
# Received MIDI message: note_on channel=0 note=72 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=74 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=81 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=80 velocity=112 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=105 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=81 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=39 time=0
# Received MIDI message: note_on channel=0 note=80 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=79 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=76 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=83 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=80 velocity=13 time=0
# Received MIDI message: note_on channel=0 note=75 velocity=24 time=0
# Received MIDI message: note_on channel=0 note=61 velocity=65 time=0
# Received MIDI message: note_on channel=0 note=73 velocity=25 time=0
# Received MIDI message: note_on channel=0 note=63 velocity=30 time=0
# Received MIDI message: note_on channel=0 note=73 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=61 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=63 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=75 velocity=0 time=0
# Received MIDI message: note_on channel=0 note=80 velocity=0 time=0
#
# Exiting MIDI listener.

# %%
def print_available_ports():
    print("Available MIDI Input Ports:")
    for port, name in enumerate(mido.get_input_names()):
        print(f"{port}: {name}")

# Call the function to print available ports
print_available_ports()
# Out:
# Available MIDI Input Ports:
# 0: Impact GX Mini MIDI1
# 1: Impact GX Mini MIDI2
# 2: Virtuele uitgang GarageBand
